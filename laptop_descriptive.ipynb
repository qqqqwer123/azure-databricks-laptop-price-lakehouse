# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_name = r'cleaned_laptop_data.csv'
df=pd.read_csv(file_name)

# %%
# 畫出價格的分佈
sns.histplot(df['price'], kde=True, color='skyblue')
plt.title('Laptop Price Distribution')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.show()

# %%
#品牌與價格帶
plt.figure(figsize=(12, 8))
# 依照中位數排序品牌，會讓圖表更好讀
order = df.groupby('brand')['price'].median().sort_values(ascending=False).index

sns.boxplot(data=df, x='price', y='brand', order=order, palette='viridis')
plt.title('Price Range by Brand (Ranked by Median Price)')
plt.show()
#中間的那條線是中位數。箱子越往右移，代表該品牌整體越貴。如果箱子外有很多「點點」，代表該品牌有很多極高價的旗艦機（Outliers）
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_34840\3403698383.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='price', y='brand', order=order, palette='viridis')
